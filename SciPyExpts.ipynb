# %% [markdown]
# <a href="https://colab.research.google.com/github/vjkr/AIKT_EE_Libraries/blob/main/SciPyExpts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Expt 1: Generating Sine Wave using Numpy

# %% [markdown]
# **Expression for Sine wave --> v=(Vm sin 2 x pi x f x t)**

# %%
# @title
import numpy as np
import matplotlib.pyplot as plt

# Parameters
amplitude = 1  # Amplitude of the sine wave
frequency = 1  # Frequency of the sine wave (in Hz)
duration = 1  # Duration of the sine wave (in seconds)
sampling_rate = 1000  # Sampling rate (in samples per second)

# Generate time vector
t = np.linspace(0, duration, int(duration * sampling_rate), endpoint=False)

# Generate sine wave
sine_wave = amplitude * np.sin(2 * np.pi * frequency * t)

# Plot the sine wave
plt.figure(figsize=(10, 6))
plt.plot(t, sine_wave)
plt.title('Sine Wave')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.grid(True)
plt.show()

# %%
# @title
import numpy as np
import matplotlib.pyplot as plt

# Parameters
amplitude = 1  # Amplitude of the sine wave
frequency = 1  # Frequency of the sine wave (in Hz)
duration = 1  # Duration of the sine wave (in seconds)
sampling_rate = 1000  # Sampling rate (in samples per second)
dc_offset = 0.5  # DC offset of the sine wave
phase_shift = np.pi / 2 # Phase shift of the sine wave (in radians)

# Generate time vector
t = np.linspace(0, duration, int(duration * sampling_rate), endpoint=False)

# Generate sine wave with DC offset and phase shift
sine_wave = amplitude * np.sin(2 * np.pi * frequency * t + phase_shift) + dc_offset

# Plot the sine wave
plt.figure(figsize=(10, 6))
plt.plot(t, sine_wave)
plt.title('Sine Wave with DC Offset and Phase Shift')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.grid(True)
plt.show()

# %%
# @title
import numpy as np
import matplotlib.pyplot as plt

# Parameters
amplitude = 1  # Amplitude of the sine wave
frequency = 1  # Frequency of the sine wave (in Hz)
duration = 1  # Duration of the sine wave (in seconds)
sampling_rate = 1000  # Sampling rate (in samples per second)
dc_offset = 0.5  # DC offset of the sine wave
phase_shift = 0  # Phase shift of the sine wave (in radians) np.pi / 2

# Generate time vector
t = np.linspace(0, duration, int(duration * sampling_rate), endpoint=False)

# Generate sine wave
sine_wave = amplitude * np.sin(2 * np.pi * frequency * t)

# Add DC offset and phase shift
sine_wave_modified = sine_wave + dc_offset
sine_wave_shifted = amplitude * np.sin(2 * np.pi * frequency * t + phase_shift)

# Plot the sine wave with DC offset and phase shift
plt.figure(figsize=(10, 6))
plt.plot(t, sine_wave, label='Sine Wave')
plt.plot(t, sine_wave_modified, label='Sine Wave with DC Offset')
plt.plot(t, sine_wave_shifted, label='Sine Wave with Phase Shift')
plt.title('Sine Wave with Modifications')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)
plt.show()

# %%
# @title
import numpy as np
import matplotlib.pyplot as plt

# Parameters
amplitude = 1  # Amplitude of the sine wave
frequency = 1  # Frequency of the sine wave (in Hz)
duration = 1  # Duration of the sine wave (in seconds)
sampling_rate = 1000  # Sampling rate (in samples per second)

# Generate time vector
t = np.linspace(0, duration, int(duration * sampling_rate), endpoint=False)

# Generate sine wave
sine_wave = amplitude * np.sin(2 * np.pi * frequency * t)

# Square the sine wave to get a squared sine wave
squared_sine_wave = np.square(sine_wave)

# Plot the squared sine wave
plt.figure(figsize=(10, 6))
plt.plot(t, squared_sine_wave)
plt.title('Squared Sine Wave')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.grid(True)
plt.show()

# %%
# @title
import numpy as np
import matplotlib.pyplot as plt

# Parameters
amplitude = 2  # Amplitude of the sine wave
frequency = 10  # Frequency of the sine wave (in Hz)
duration = 0.1  # Duration of the sine wave (in seconds)
sampling_rate = 1000  # Sampling rate (in samples per second)
dc_offset = 1  # DC offset of the sine wave

# Generate time vector
t = np.linspace(0, duration, int(duration * sampling_rate), endpoint=False)

# Generate sine wave
sine_wave = amplitude * np.sin(2 * np.pi * frequency * t)

# Add DC offset
sine_wave_modified = sine_wave + dc_offset

# Square the sine wave
squared_sine_wave = np.square(sine_wave)

# Plot all three waves
plt.figure(figsize=(12, 8))
plt.plot(t, sine_wave, label='Sine Wave')
plt.plot(t, sine_wave_modified, label='Sine Wave with DC Offset')
plt.plot(t, squared_sine_wave, label='Squared Sine Wave')
plt.title('Waveforms')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Expt 2: Fast Fourier Transform

# %%
# @title
import numpy as np
import matplotlib.pyplot as plt

# Parameters
duration = 1  # Duration of the signal (in seconds)
sampling_rate = 100  # Sampling rate (in samples per second)
frequency1 = 5  # Frequency of the first component (in Hz)
frequency2 = 10  # Frequency of the second component (in Hz)
amplitude1 = 1  # Amplitude of the first component
amplitude2 = 0.5  # Amplitude of the second component

# Generate time vector
t = np.linspace(0, duration, int(duration * sampling_rate), endpoint=False)

# Generate signal with two frequency components
signal = amplitude1 * np.sin(2 * np.pi * frequency1 * t) + amplitude2 * np.sin(2 * np.pi * frequency2 * t)

# Perform Fourier Transform
fft_result = np.fft.fft(signal)
frequencies = np.fft.fftfreq(len(signal), 1 / sampling_rate)

# Plot the signal
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plt.plot(t, signal)
plt.title('Signal with Two Frequency Components')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.grid(True)

# Plot the Fourier Transform
plt.subplot(2, 1, 2)
plt.plot(frequencies[:len(frequencies)//2], np.abs(fft_result)[:len(frequencies)//2])
plt.title('Fourier Transform of the Signal')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.grid(True)

plt.tight_layout()
plt.show()
